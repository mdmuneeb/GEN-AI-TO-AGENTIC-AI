# %%
from langchain_community.document_loaders import TextLoader, PyPDFLoader, DirectoryLoader, UnsrtucturedFileLoader

# %%
loader = TextLoader("./Module2data/sample.txt")
documents = loader.load()

# %%
print(documents)

# %%
documents.page_content

# %%
pdfLoader = PyPDFLoader("../paracetamol_drug_report.pdf")
pdfDocument = pdfLoader.load()

# %%
pdfDocument.page_content

# %%
dirLoader = DirectoryLoader("./Module2data/", glob="**/*.txt", loader_cls=PyPDFLoader, recursive=True)
dirDocuments = dirLoader.load()
for doc in dirDocuments:
    print(doc.page_content)

# %% [markdown]
# Chunking Startegies
# - Text-based Chunking
# - Document-based Chunking
# - Contextual Chunking by Anthropic

# %%
# Out:
# The kernel failed to start as the Python Environment 'CLASSES (Python -1.-1.-1)' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.
